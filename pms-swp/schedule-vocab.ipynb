# %% [markdown]
# # Το πρώτο σας λεξιλόγιο RDFS
#
# Στην παρούσα άσκηση θα φτιάξετε **το δικό σας** λεξιλόγιο RDFS για τα δεδομένα του ωρολογίου προγράμματός σας.
#
# ---------------
#
# *_**Σημείωση:** Το παρόν αποτελεί την **πρώτη εργασία** του μαθήματος και το τελικό αποτέλεσμα θα παρέχει μέρος της συνολικής σας βαθμολογίας στο μάθημα του “Προγραμματισμού του Σημασιολογικού Ιστού”.*
#
# ---------------
#
# ## 1. Το μορφότυπο Turtle
#
# Θα έχετε παρατηρήσει από τα προηγούμενα εργαστήρια ότι η μορφή N-Triples δεν είναι ιδιαιτέρως φιλική, ειδικά όταν πρέπει να γράψετε τριάδες “στο χέρι”. Για τον λόγο αυτόν θα χρησιμοποιήσετε εδώ τη μορφή **Turtle** που παρέχει συντομέυσεις για μια πιο συμπαγή γραφή των τριάδων.
#
# Λεπτομέρειες για την Turtle μπορείτε να δείτε στο [σύγγραμα του μαθήματος (ενότητα 2.16)](http://hdl.handle.net/11419/1338). Στη συνέχεια δίνονται μερικά συνοπτικά στοιχεία:
#
# * Δεν είναι υποχρεωτικό μια τριάδα να γραφεί στην ίδια γραμμή (μπορεί να καταλαμβάνει περισσότερες).
#
# * Μπορούμε να χρησιμοποιήσουμε **συντομογραφικά προθέματα** με τους χώρους ονομάτων (namespaces) των URIs με τη βοήθεια του @prefix:
#
#     ```
#     @prefix dc: <http://purl.org/dc/elements/1.1/> .
#     ```
#
#     ή ακόμα και:
#
#     ```
#     PREFIX dc: <http://purl.org/dc/elements/1.1/>
#     ```
#
# * Το κατηγόρημα **rdf:type** είναι τόσο κοινό που μπορεί να συντομευθεί με τη λέξη `a` ως εξής:
#
#     ```
#     uni:Student a rdfs:Class .
#     ```
#
# * Όταν έχουμε τριάδες με **κοινό υποκείμενο** μπορούμε να τις συνοψίσουμε με τη βοήθεια του **ερωτηματικού** ( ; ) π.χ. το:
#
#     ```
#     <http://www.bbc.co.uk/programmes/b03jprmh#programme> dc:title "The Firemaker" ;
#                                                          po:position 4 .
#     ```
#
#     είναι ισοδύναμο με τις 2 τριάδες (σε μορφή N-Triples):
#
#     ```
#     <http://www.bbc.co.uk/programmes/b03jprmh#programme> dc:title "The Firemaker" .
#
#     <http://www.bbc.co.uk/programmes/b03jprmh#programme> po:position 4 .
#     ```
#
# * Παρομοίως, μπορούμε με το **κόμμα** ( , ) να συνοψίσουμε τριάδες με **κοινό
# υποκείμενο και κατηγόρημα**, π.χ. το:
#
#     ```
#     <http://www.bbc.co.uk/programmes/p00jxl63#programme> po:episode
#     <http://www.bbc.co.uk/programmes/b03jprmh#programme>,
#     <http://www.bbc.co.uk/programmes/b03jprm9#programme> .
#     ```
#
#     είναι ισοδύναμο με τις δύο τριάδες N-Triples:
#
#     ```
#     <http://www.bbc.co.uk/programmes/p00jxl63#programme> po:episode
#     <http://www.bbc.co.uk/programmes/b03jprmh#programme> .
#     <http://www.bbc.co.uk/programmes/p00jxl63#programme> po:episode
#     <http://www.bbc.co.uk/programmes/b03jprm9#programme> .
#     ```
#
# ## 2. Δημιουργήστε το δικό σας λεξιλόγιο RDF για τα δεδομένα του ωρολογίου προγράμματος
#
# * Από την αρχική σελίδα σας στο Jupyterhub (**όχι εδώ!**) δημιουργήστε ένα νέο αρχείο κειμένου (**New -> Text file**).
#
# * Ως γλώσσα επιλέξτε την Turtle (**Language -> Turtle**).
#
# * Μετονομάστε το αρχείο χρησιμοποιώντας κατάληξη **.ttl**
#
# * Συνεχίστε προσθέτοντας τα επόμενα στο αρχείο Turtle.
#
# *Σημείωση: Καλό είναι κατά διαστήματα να ελέγχετε αν το αρχείο είναι έγκυρο μέσω του `riot` - εκτελέστε εδώ π.χ. (στο επόμενο κελί) αφού σώσετε τις αλλαγές στο αρχείο ttl:*
#
# ```
# !riot --validate yourfile.ttl
# ```
#
#
# ### 2.1. Ο χώρος ονομάτων σας
#
# Δηλώστε ως prefix το χώρο ονομάτων του λεξιλογίου σας, όπως τον χρησιμοποιήσατε στην προηγούμενη άσκηση για τα κατηγορήματα:
#
# ```
# http://dilab77.ionio.gr/swp/you/vocab#
# ```
#
# όπου you πρέπει να είναι το username που έχετε στο JupyterHub.
#
# Δηλώστε επίσης τα προθέματα `rdf:` `(http://www.w3.org/1999/02/22-rdf-syntax-ns#)`, `rdfs:` `(http://www.w3.org/2000/01/rdf-schema#)` και `xsd:` `(http://www.w3.org/2001/XMLSchema#)`.
#
# ### 2.2. Οι κλάσεις σας
#
# Περιγράψτε μέσω του RDFS τις κλάσεις:
#
# * Διδάσκων
# * Διάλεξη
# * Αίθουσα
# * Μάθημα
#
# **Υπόδειξη:** Χρησιμοποιήστε URIs στον χώρο ονομάτων σας, με το όνομα της κλάσης να αρχίζει με κεφαλαίο γράμμα. Χρησιμοποιήστε τα `rdf:type` και `rdfs:Class` για τον σκοπό αυτό.
#
# Περιγράψτε επίσης ότι ο Διδάσκων είναι υποκλάση της `foaf:Person`. Μην ξεχάσετε να δηλώσετε και το πρόθεμα `foaf` (για το πρόθεμα μπορείτε να συμβουλευτείτε το [prefix.cc](http://prefix.cc/)).
#
# ### 2.3. Οι ιδιότητες
#
# Περιγράψτε μέσω του RDFS τις ιδιότητες που χρησιμοποιείτε ως κατηγορήματα.
#
# **Υπόδειξη:** Χρησιμοποιήστε τα `rdf:type` και `rdf:Property`.
#
# Περιγράψτε επίσης τα πεδία ορισμού (domain) και σύνολα τιμών (range) για τα κατηγορήματά σας.
#
# ### 2.4 Ελέγξτε την εγκυρότητα του αρχείου Turtle
#
# Τελειώνοντας, μην ξεχάσετε να ελέγξετε αν το αρχείο του λεξιλογίου σας έχει έγκυρη μορφή Turtle
# (εκτελέστε το επόμενο κελί).

# %%
# αφαιρέστε τα σχόλια και εκτελέστε το παρακάτω
#!riot --validate yourfile.ttl

# %% [markdown]
# ## 3. Σύνδεση των δεδομένων με το λεξιλόγιο
#
# Το αρχείο Turtle που φτιάξατε στο προηγούμενο βήμα περιγράφει το σχήμα των δεδομένων σας. Θα πρέπει όμως στη συνέχεια να **συνδέσετε** τα αρχικά σας δεδομένα με το λεξιλόγιο. Πώς θα γίνει αυτό;
#
# Για κάθε URI των οντοτήτων σας, θα πρέπει να προστεθεί (στα δεδομένα πάντα - **όχι στο αρχείο ttl!**) μια τριάδα της μορφής:
#
# ```
# <your-uri> rdf:type <type-of-this-uri> .
# ```
#
# Αυτό πρέπει να γίνει για κάθε URI οντότητας, δηλαδή
#
# * για τις διαλέξεις (ανώνυμοι κόμβοι στη θέση υποκειμένου)
#
# * για τους διδάσκοντες (URIs σε θέση αντικειμένου)
#
# * για τα μαθήματα (URIs σε θέση αντικειμένου)
#
# * για τις αίθουσες (URIs σε θέση αντικειμένου)
#
# ### 3.1 Πώς θα το κάνετε
#
# Φυσικά, μέσω Python. Μπορείτε να αντιγράψετε το [notebook της προηγούμενης άσκησης](https://github.com/mixstef/courses/blob/master/pms-swp/schedule4.ipynb) τροποποιώντας το κατάλληλα: προσθέστε τον κώδικά σας πριν από την παραγωγή των N-Triples (δηλ. αμέσως πριν το τμήμα 3), έτσι ώστε να εισάγετε και τις ζητούμενες τριάδες με το κατηγόρημα `rdf:type`.
#
# **Προσοχή!** Δεν πρέπει να δηλώσετε τύπο για κάθε URI πάνω από μία φορά!
#
# Αυτό μπορεί να γίνει π.χ. μέσω ενός `set`. Χρησιμοποιήστε το για να κρατάτε τα URIs που έχετε δει ως τώρα:
#
# ```python
# visited = set()
#
# # ...
# if uri not in visited:
#     # προσθέστε τριάδα με rdf:type
#     visited.add(uri)
# ```
#
# Το παραπάνω θα εξασφαλίσει ότι θα εισάγετε τον τύπο RDF του URI **μόνο μία φορά**.

# %% [markdown]
# # 4. Παράδοση εργασίας
#
# Η παράδοση θα γίνει **μέσω github** (δημιουργήστε λογαριασμό αν δεν έχετε ήδη).
#
# ## Οδηγίες:
#
# 1. Αντιγράψτε (με **fork**) το repository https://github.com/mixstef/pmsswp1617a1 στο δικό σας repository.
#
# 2. Τροποποιήστε κατάλληλα τα αρχεία που περιέχονται στο repository σας με το δικό σας περιεχόμενο:
#
#     * Συμπληρώστε τα στοιχεία σας στο αρχείο **README.md** .
#
#     * Προσθέστε στο αρχείο Turtle **schedule-vocab.ttl** το λεξιλόγιο RDFS (βήμα 2 άσκησης).
#
#     * Προσθέστε στο αρχείο N-Triples **schedule-data.nt** τα δεδομένα και τις δηλώσεις rdf:type (βήμα 3 άσκησης).
#
#     * Προσθέστε στο notebook **create-types.ipynb** τον κώδικα python που χρησιμοποιήσατε για την παραγωγή του **schedule-data.nt** .
#
#     * **Προσοχή: πρέπει να διατηρήσετε τα ονόματα των παραπάνω αρχείων!**
#
# 3. Ενημερώστε το repository σας στο github εντός προθεσμίας.
#
# Η εργασία είναι **αυστηρά ατομική**. Για την εγκυρότητα της υποβολής σας θα χρησιμοποιηθεί η χρονοσήμανση των αλλαγών (commits) των αρχείων σας.
#
# *Τα δύο αρχεία τριάδων (schedule-vocab.ttl και schedule-data.nt) θα πρέπει να είναι έγκυρα και να περνούν από το riot χωρίς σφάλματα!*
#
#
#
# **Προθεσμία παράδοσης: 24/4/2017 **
